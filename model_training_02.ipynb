# %%
# import packages and data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import joblib
import warnings
warnings.filterwarnings('ignore')

tr_features = pd.read_csv('./x_train_features_02.csv')
tr_labels = pd.read_csv('./y_train_labels_02.csv')

# %%
def print_results(results):
    print(f'Best Params: {results.best_params_}')
    
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    
    print('Test results:')
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean, 3)} (+/-{round(std, 3)}) for {params}')
        
        
def pkl_best_params(results, model_type: str):
    joblib.dump(results.best_estimator_, f'./{model_type}_model.pkl')
    
    
def plot_performance(results):
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    best_est = results.best_estimator_
    columns = list(results.cv_results_)
    rows = [f'{x}' for x in results.cv_results_['params']]
    nrows = len(results.cv_results_)      
    
    
    plt.figure(figsize=(16,9))
    plt.bar(rows, means)
    plt.xticks(rotation=45, ha="right")
    
    plt.show()

# %%
lr = LogisticRegression(max_iter=500)
params = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}

lr_cv = GridSearchCV(lr, params, cv=5) # creates the cross-validation object
lr_cv.fit(tr_features, tr_labels.values.ravel()) # .ravel() converts tr_labels from an object vector to an array

print_results(lr_cv)
# Out:
# Best Params: {'C': 10}
# Test results:
# 0.549 (+/-0.002) for {'C': 0.001}
# 0.631 (+/-0.011) for {'C': 0.01}
# 0.702 (+/-0.02) for {'C': 0.1}
# 0.724 (+/-0.018) for {'C': 1}
# 0.725 (+/-0.019) for {'C': 10}
# 0.722 (+/-0.026) for {'C': 100}
# 0.723 (+/-0.025) for {'C': 1000}

# %%
plot_performance(lr_cv)

# %%
# save best params as pkl

pkl_best_params(lr_cv, 'LR')

# %%
# create support vector machine model

svc = SVC()
svc_params = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10]
}

svc_cv = GridSearchCV(svc, svc_params, cv=5)
svc_cv.fit(tr_features, tr_labels.values.ravel())

print_results(svc_cv)
# Out:
# Best Params: {'C': 10, 'kernel': 'rbf'}
# Test results:
# 0.709 (+/-0.028) for {'C': 0.1, 'kernel': 'linear'}
# 0.743 (+/-0.024) for {'C': 0.1, 'kernel': 'poly'}
# 0.722 (+/-0.023) for {'C': 0.1, 'kernel': 'rbf'}
# 0.549 (+/-0.002) for {'C': 0.1, 'kernel': 'sigmoid'}
# 0.732 (+/-0.019) for {'C': 1, 'kernel': 'linear'}
# 0.757 (+/-0.017) for {'C': 1, 'kernel': 'poly'}
# 0.752 (+/-0.017) for {'C': 1, 'kernel': 'rbf'}
# 0.513 (+/-0.028) for {'C': 1, 'kernel': 'sigmoid'}
# 0.741 (+/-0.023) for {'C': 10, 'kernel': 'linear'}
# 0.764 (+/-0.028) for {'C': 10, 'kernel': 'poly'}
# 0.766 (+/-0.03) for {'C': 10, 'kernel': 'rbf'}
# 0.445 (+/-0.02) for {'C': 10, 'kernel': 'sigmoid'}

# %%
plot_performance(svc_cv)

# %%
# save best params as pkl

pkl_best_params(svc_cv, 'SVM')

# %%
# create multi-layer perceptron model

mlp = MLPClassifier()
mlp_params = {
    'hidden_layer_sizes':[(10,), (10,2), (50,), (100,)],
    'activation': ['relu', 'tanh', 'logistic'],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

mlp_cv = GridSearchCV(mlp, mlp_params, cv=5)
mlp_cv.fit(tr_features, tr_labels.values.ravel())

print_results(mlp_cv)
# Out:
# Best Params: {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# Test results:
# 0.72 (+/-0.022) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.723 (+/-0.018) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.723 (+/-0.023) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.571 (+/-0.1) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.722 (+/-0.017) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.723 (+/-0.014) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.721 (+/-0.021) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.719 (+/-0.016) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.725 (+/-0.02) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.729 (+/-0.016) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.731 (+/-0.009) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.73 (+/-0.021) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.724 (+/-0.022) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.728 (+/-0.032) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.722 (+/-0.015) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.732 (+/-0.033) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.72 (+/-0.031) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.72 (+/-0.027) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.722 (+/-0.016) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.722 (+/-0.024) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.721 (+/-0.02) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.727 (+/-0.019) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.723 (+/-0.017) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.721 (+/-0.019) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.71 (+/-0.014) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.711 (+/-0.014) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.717 (+/-0.013) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.66 (+/-0.072) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.644 (+/-0.079) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.634 (+/-0.069) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.724 (+/-0.029) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.722 (+/-0.028) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.72 (+/-0.031) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.718 (+/-0.023) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.722 (+/-0.025) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.723 (+/-0.02) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}

# %%
# save best params as pkl

pkl_best_params(mlp_cv, 'MLP')

# %%
plot_performance(mlp_cv)

# %%
# create random forest model

rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [5, 50, 250],
    'max_depth': [2, 4, 8, 16, 32, None]
}

rf_cv = GridSearchCV(rf, rf_params, cv=5)
rf_cv.fit(tr_features, tr_labels.values.ravel())

print_results(rf_cv)
# Out:
# Best Params: {'max_depth': 32, 'n_estimators': 250}
# Test results:
# 0.702 (+/-0.032) for {'max_depth': 2, 'n_estimators': 5}
# 0.737 (+/-0.022) for {'max_depth': 2, 'n_estimators': 50}
# 0.732 (+/-0.033) for {'max_depth': 2, 'n_estimators': 250}
# 0.743 (+/-0.041) for {'max_depth': 4, 'n_estimators': 5}
# 0.76 (+/-0.045) for {'max_depth': 4, 'n_estimators': 50}
# 0.767 (+/-0.045) for {'max_depth': 4, 'n_estimators': 250}
# 0.756 (+/-0.039) for {'max_depth': 8, 'n_estimators': 5}
# 0.791 (+/-0.039) for {'max_depth': 8, 'n_estimators': 50}
# 0.785 (+/-0.044) for {'max_depth': 8, 'n_estimators': 250}
# 0.764 (+/-0.034) for {'max_depth': 16, 'n_estimators': 5}
# 0.791 (+/-0.022) for {'max_depth': 16, 'n_estimators': 50}
# 0.793 (+/-0.029) for {'max_depth': 16, 'n_estimators': 250}
# 0.748 (+/-0.026) for {'max_depth': 32, 'n_estimators': 5}
# 0.784 (+/-0.036) for {'max_depth': 32, 'n_estimators': 50}
# 0.796 (+/-0.031) for {'max_depth': 32, 'n_estimators': 250}
# 0.765 (+/-0.042) for {'max_depth': None, 'n_estimators': 5}
# 0.793 (+/-0.037) for {'max_depth': None, 'n_estimators': 50}
# 0.793 (+/-0.036) for {'max_depth': None, 'n_estimators': 250}

# %%
plot_performance(rf_cv)

# %%
# save best params as pkl

pkl_best_params(rf_cv, 'RF')

# %%
# create gradient boosting model

gbm = GradientBoostingClassifier()
gbm_params = {
    'n_estimators': [5, 50, 250, 500],
    'max_depth': [1, 2, 3, 5, 8],
    'learning_rate': [0.01, 0.1, 1, 10, 100]
}

gbm_cv = GridSearchCV(gbm, gbm_params, cv=5)
gbm_cv.fit(tr_features, tr_labels.values.ravel())

print_results(gbm_cv)
# Out:
# Best Params: {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# Test results:
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5}
# 0.7 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50}
# 0.738 (+/-0.04) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 250}
# 0.758 (+/-0.045) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 5}
# 0.758 (+/-0.046) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50}
# 0.77 (+/-0.042) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 250}
# 0.77 (+/-0.043) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5}
# 0.758 (+/-0.04) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# 0.776 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250}
# 0.776 (+/-0.03) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5}
# 0.766 (+/-0.03) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# 0.786 (+/-0.037) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 250}
# 0.788 (+/-0.035) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 5}
# 0.762 (+/-0.037) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
# 0.772 (+/-0.034) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 250}
# 0.783 (+/-0.029) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 500}
# 0.7 (+/-0.039) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5}
# 0.758 (+/-0.043) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.782 (+/-0.04) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# 0.78 (+/-0.036) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.751 (+/-0.042) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 5}
# 0.77 (+/-0.042) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.765 (+/-0.038) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 250}
# 0.769 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500}
# 0.765 (+/-0.043) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5}
# 0.776 (+/-0.037) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.774 (+/-0.042) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
# 0.776 (+/-0.04) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.767 (+/-0.032) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5}
# 0.791 (+/-0.037) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# 0.782 (+/-0.036) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 250}
# 0.771 (+/-0.025) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# 0.748 (+/-0.033) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 5}
# 0.777 (+/-0.029) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 50}
# 0.783 (+/-0.032) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 250}
# 0.785 (+/-0.033) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 500}
# 0.732 (+/-0.04) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 5}
# 0.766 (+/-0.028) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.769 (+/-0.044) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 250}
# 0.759 (+/-0.051) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.744 (+/-0.028) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 5}
# 0.741 (+/-0.038) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50}
# 0.756 (+/-0.032) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 250}
# 0.761 (+/-0.04) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 500}
# 0.769 (+/-0.028) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 5}
# 0.746 (+/-0.044) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.756 (+/-0.037) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 250}
# 0.767 (+/-0.041) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
# 0.732 (+/-0.037) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 5}
# 0.764 (+/-0.038) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.793 (+/-0.029) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# 0.78 (+/-0.036) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 500}
# 0.751 (+/-0.024) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 5}
# 0.78 (+/-0.043) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 50}
# 0.785 (+/-0.038) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 250}
# 0.785 (+/-0.042) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 500}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 5}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 50}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 250}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 500}
# 0.337 (+/-0.094) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 5}
# 0.337 (+/-0.094) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 50}
# 0.337 (+/-0.094) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 250}
# 0.337 (+/-0.094) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 500}
# 0.394 (+/-0.078) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 5}
# 0.394 (+/-0.078) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 50}
# 0.394 (+/-0.078) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 250}
# 0.394 (+/-0.078) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 500}
# 0.486 (+/-0.103) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 5}
# 0.462 (+/-0.083) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 50}
# 0.53 (+/-0.082) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 250}
# 0.442 (+/-0.061) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 500}
# 0.62 (+/-0.05) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 5}
# 0.591 (+/-0.055) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 50}
# 0.563 (+/-0.09) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 250}
# 0.578 (+/-0.067) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 500}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 5}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 50}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 250}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 500}
# 0.423 (+/-0.047) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 5}
# 0.423 (+/-0.047) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 50}
# 0.423 (+/-0.047) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 250}
# 0.423 (+/-0.047) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 500}
# 0.378 (+/-0.049) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 5}
# 0.378 (+/-0.049) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 50}
# 0.376 (+/-0.051) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 250}
# 0.378 (+/-0.049) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 500}
# 0.343 (+/-0.114) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 5}
# 0.345 (+/-0.113) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 50}
# 0.341 (+/-0.114) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 250}
# 0.341 (+/-0.114) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 500}
# 0.491 (+/-0.02) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 5}
# 0.464 (+/-0.046) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 50}
# 0.447 (+/-0.104) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 250}
# 0.439 (+/-0.09) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 500}

# %%
plot_performance(gbm_cv)

# %%
# save best params as pkl

pkl_best_params(gbm_cv, 'GBM')
