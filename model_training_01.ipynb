# %%
# import packages and data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import joblib
import warnings
warnings.filterwarnings('ignore')

tr_features = pd.read_csv('./x_train_features.csv')
tr_labels = pd.read_csv('./y_train_labels.csv')

# %%
def print_results(results):
    print(f'Best Params: {results.best_params_}')
    
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    
    print('Test results:')
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean, 3)} (+/-{round(std, 3)}) for {params}')
        
        
def pkl_best_params(results, model_type: str):
    joblib.dump(results.best_estimator_, f'./{model_type}_model.pkl')
    
    
def plot_performance(results):
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    best_est = results.best_estimator_
    columns = list(results.cv_results_)
    rows = [f'{x}' for x in results.cv_results_['params']]
    nrows = len(results.cv_results_)      
    
    
    plt.figure(figsize=(16,9))
    plt.bar(rows, means)
    plt.xticks(rotation=45, ha="right")
    
    plt.show()

# %%
lr = LogisticRegression(max_iter=500)
params = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}

lr_cv = GridSearchCV(lr, params, cv=5) # creates the cross-validation object
lr_cv.fit(tr_features, tr_labels.values.ravel()) # .ravel() converts tr_labels from an object vector to an array

print_results(lr_cv)
# Out:
# Best Params: {'C': 100}
# Test results:
# 0.549 (+/-0.002) for {'C': 0.001}
# 0.551 (+/-0.019) for {'C': 0.01}
# 0.657 (+/-0.015) for {'C': 0.1}
# 0.674 (+/-0.032) for {'C': 1}
# 0.684 (+/-0.024) for {'C': 10}
# 0.696 (+/-0.023) for {'C': 100}
# 0.695 (+/-0.023) for {'C': 1000}

# %%
plot_performance(lr_cv)

# %%
# save best params as pkl

pkl_best_params(lr_cv, 'LR')

# %%
# create support vector machine model

svc = SVC()
svc_params = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10]
}

svc_cv = GridSearchCV(svc, svc_params, cv=5)
svc_cv.fit(tr_features, tr_labels.values.ravel())

print_results(svc_cv)
# Out:
# Best Params: {'C': 10, 'kernel': 'poly'}
# Test results:
# 0.668 (+/-0.017) for {'C': 0.1, 'kernel': 'linear'}
# 0.723 (+/-0.032) for {'C': 0.1, 'kernel': 'poly'}
# 0.678 (+/-0.025) for {'C': 0.1, 'kernel': 'rbf'}
# 0.545 (+/-0.005) for {'C': 0.1, 'kernel': 'sigmoid'}
# 0.681 (+/-0.024) for {'C': 1, 'kernel': 'linear'}
# 0.737 (+/-0.027) for {'C': 1, 'kernel': 'poly'}
# 0.724 (+/-0.029) for {'C': 1, 'kernel': 'rbf'}
# 0.384 (+/-0.029) for {'C': 1, 'kernel': 'sigmoid'}
# 0.711 (+/-0.023) for {'C': 10, 'kernel': 'linear'}
# 0.746 (+/-0.035) for {'C': 10, 'kernel': 'poly'}
# 0.73 (+/-0.029) for {'C': 10, 'kernel': 'rbf'}
# 0.359 (+/-0.016) for {'C': 10, 'kernel': 'sigmoid'}

# %%
plot_performance(svc_cv)

# %%
# save best params as pkl

pkl_best_params(svc_cv, 'SVM')

# %%
# create multi-layer perceptron model

mlp = MLPClassifier()
mlp_params = {
    'hidden_layer_sizes':[(10,), (10,2), (50,), (100,)],
    'activation': ['relu', 'tanh', 'logistic'],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

mlp_cv = GridSearchCV(mlp, mlp_params, cv=5)
mlp_cv.fit(tr_features, tr_labels.values.ravel())

print_results(mlp_cv)
# Out:
# Best Params: {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# Test results:
# 0.663 (+/-0.04) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.66 (+/-0.011) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.673 (+/-0.026) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.617 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.628 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.626 (+/-0.063) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.677 (+/-0.016) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.684 (+/-0.023) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.689 (+/-0.02) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.701 (+/-0.029) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.699 (+/-0.029) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.691 (+/-0.032) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.66 (+/-0.015) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.666 (+/-0.01) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.668 (+/-0.021) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.681 (+/-0.021) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.681 (+/-0.024) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.678 (+/-0.017) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.676 (+/-0.029) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.669 (+/-0.022) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.677 (+/-0.031) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.677 (+/-0.026) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.675 (+/-0.022) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.673 (+/-0.029) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.65 (+/-0.02) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.654 (+/-0.02) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.622 (+/-0.038) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.549 (+/-0.002) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.552 (+/-0.006) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.563 (+/-0.025) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.66 (+/-0.012) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.659 (+/-0.007) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.665 (+/-0.005) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.666 (+/-0.011) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.665 (+/-0.01) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.665 (+/-0.008) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}

# %%
# save best params as pkl

pkl_best_params(mlp_cv, 'MLP')

# %%
plot_performance(mlp_cv)

# %%
# create random forest model

rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [5, 50, 250],
    'max_depth': [2, 4, 8, 16, 32, None]
}

rf_cv = GridSearchCV(rf, rf_params, cv=5)
rf_cv.fit(tr_features, tr_labels.values.ravel())

print_results(rf_cv)
# Out:
# Best Params: {'max_depth': 32, 'n_estimators': 250}
# Test results:
# 0.699 (+/-0.025) for {'max_depth': 2, 'n_estimators': 5}
# 0.719 (+/-0.042) for {'max_depth': 2, 'n_estimators': 50}
# 0.717 (+/-0.036) for {'max_depth': 2, 'n_estimators': 250}
# 0.73 (+/-0.038) for {'max_depth': 4, 'n_estimators': 5}
# 0.739 (+/-0.035) for {'max_depth': 4, 'n_estimators': 50}
# 0.733 (+/-0.041) for {'max_depth': 4, 'n_estimators': 250}
# 0.735 (+/-0.033) for {'max_depth': 8, 'n_estimators': 5}
# 0.762 (+/-0.033) for {'max_depth': 8, 'n_estimators': 50}
# 0.761 (+/-0.029) for {'max_depth': 8, 'n_estimators': 250}
# 0.73 (+/-0.022) for {'max_depth': 16, 'n_estimators': 5}
# 0.762 (+/-0.027) for {'max_depth': 16, 'n_estimators': 50}
# 0.762 (+/-0.027) for {'max_depth': 16, 'n_estimators': 250}
# 0.752 (+/-0.034) for {'max_depth': 32, 'n_estimators': 5}
# 0.77 (+/-0.027) for {'max_depth': 32, 'n_estimators': 50}
# 0.775 (+/-0.021) for {'max_depth': 32, 'n_estimators': 250}
# 0.706 (+/-0.038) for {'max_depth': None, 'n_estimators': 5}
# 0.757 (+/-0.031) for {'max_depth': None, 'n_estimators': 50}
# 0.77 (+/-0.023) for {'max_depth': None, 'n_estimators': 250}

# %%
plot_performance(rf_cv)

# %%
# save best params as pkl

pkl_best_params(rf_cv, 'RF')

# %%
# create gradient boosting model

gbm = GradientBoostingClassifier()
gbm_params = {
    'n_estimators': [5, 50, 250, 500],
    'max_depth': [1, 2, 3, 5, 8],
    'learning_rate': [0.01, 0.1, 1, 10, 100]
}

gbm_cv = GridSearchCV(gbm, gbm_params, cv=5)
gbm_cv.fit(tr_features, tr_labels.values.ravel())

print_results(gbm_cv)
# Out:
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# Test results:
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5}
# 0.7 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50}
# 0.703 (+/-0.044) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 250}
# 0.716 (+/-0.045) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 5}
# 0.708 (+/-0.046) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50}
# 0.728 (+/-0.04) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 250}
# 0.735 (+/-0.033) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5}
# 0.724 (+/-0.035) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# 0.75 (+/-0.029) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250}
# 0.753 (+/-0.032) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5}
# 0.724 (+/-0.023) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# 0.75 (+/-0.031) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 250}
# 0.756 (+/-0.016) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# 0.549 (+/-0.002) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 5}
# 0.733 (+/-0.026) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
# 0.753 (+/-0.032) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 250}
# 0.757 (+/-0.025) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 500}
# 0.7 (+/-0.039) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5}
# 0.716 (+/-0.045) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.728 (+/-0.044) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# 0.722 (+/-0.036) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.709 (+/-0.041) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 5}
# 0.739 (+/-0.032) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.728 (+/-0.024) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 250}
# 0.72 (+/-0.021) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500}
# 0.71 (+/-0.039) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5}
# 0.742 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.733 (+/-0.019) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
# 0.728 (+/-0.013) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.722 (+/-0.023) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5}
# 0.765 (+/-0.018) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# 0.763 (+/-0.014) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 250}
# 0.76 (+/-0.015) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# 0.73 (+/-0.031) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 5}
# 0.757 (+/-0.025) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 50}
# 0.757 (+/-0.02) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 250}
# 0.756 (+/-0.019) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 500}
# 0.688 (+/-0.027) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 5}
# 0.714 (+/-0.028) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.711 (+/-0.032) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 250}
# 0.712 (+/-0.038) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.698 (+/-0.039) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 5}
# 0.716 (+/-0.017) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50}
# 0.727 (+/-0.019) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 250}
# 0.722 (+/-0.014) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 500}
# 0.728 (+/-0.042) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 5}
# 0.735 (+/-0.015) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.728 (+/-0.025) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 250}
# 0.732 (+/-0.026) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
# 0.737 (+/-0.037) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 5}
# 0.74 (+/-0.019) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.745 (+/-0.027) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# 0.754 (+/-0.022) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 500}
# 0.712 (+/-0.029) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 5}
# 0.76 (+/-0.023) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 50}
# 0.755 (+/-0.027) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 250}
# 0.754 (+/-0.014) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 500}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 5}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 50}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 250}
# 0.316 (+/-0.04) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 500}
# 0.413 (+/-0.152) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 5}
# 0.413 (+/-0.152) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 50}
# 0.413 (+/-0.152) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 250}
# 0.413 (+/-0.152) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 500}
# 0.345 (+/-0.102) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 5}
# 0.345 (+/-0.102) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 50}
# 0.345 (+/-0.102) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 250}
# 0.345 (+/-0.102) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 500}
# 0.488 (+/-0.085) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 5}
# 0.464 (+/-0.084) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 50}
# 0.462 (+/-0.061) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 250}
# 0.493 (+/-0.049) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 500}
# 0.515 (+/-0.109) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 5}
# 0.5 (+/-0.041) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 50}
# 0.525 (+/-0.085) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 250}
# 0.5 (+/-0.098) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 500}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 5}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 50}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 250}
# 0.451 (+/-0.002) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 500}
# 0.346 (+/-0.065) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 5}
# 0.346 (+/-0.065) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 50}
# 0.346 (+/-0.065) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 250}
# 0.346 (+/-0.065) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 500}
# 0.344 (+/-0.056) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 5}
# 0.341 (+/-0.055) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 50}
# 0.34 (+/-0.055) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 250}
# 0.338 (+/-0.055) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 500}
# 0.463 (+/-0.056) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 5}
# 0.465 (+/-0.071) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 50}
# 0.463 (+/-0.053) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 250}
# 0.442 (+/-0.072) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 500}
# 0.489 (+/-0.082) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 5}
# 0.456 (+/-0.108) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 50}
# 0.497 (+/-0.081) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 250}
# 0.455 (+/-0.109) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 500}

# %%
plot_performance(gbm_cv)

# %%
# save best params as pkl

pkl_best_params(gbm_cv, 'GBM')
